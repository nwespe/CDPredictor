# %%
## Python packages - you may have to pip install sqlalchemy, sqlalchemy_utils, and psycopg2.
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
import pandas as pd

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dbname = 'mimic_demo_db'
username = 'nwespe'
schema_name = 'mimiciii_demo'

# %%
## 'engine' is a connection to a database
## Here, we're using postgres, but sqlalchemy can connect to other things too.
engine = create_engine('postgresql://%s@localhost/%s'%(username,dbname))
print 'postgresql://%s@localhost/%s'%(username,dbname)
print engine.url
# Replace localhost with IP address if accessing a remote server
# Out:
# postgresql://nwespe@localhost/mimic_demo_db
# postgresql://nwespe@localhost/mimic_demo_db

# %%
# connect:
con = None
con = psycopg2.connect(database = dbname, user = username, host='localhost') #, password=pswd
cur = con.cursor()
cur.execute('SET search_path to ' + schema_name)

# %%
# query:
sql_query = """
SELECT * FROM microbiologyevents;
"""
microevents = pd.read_sql_query(sql_query,con)
microevents.head()
# Out:
#    row_id  subject_id  hadm_id  chartdate           charttime  spec_itemid  \
# 0  135096       10056   100375 2129-05-02 2129-05-02 00:21:00        70079
# 1  135097       10056   100375 2129-05-02 2129-05-02 01:00:00        70012
# 2  135098       10056   100375 2129-05-02 2129-05-02 02:30:00        70012
# 3  136115       10127   182839 2198-07-16 2198-07-16 06:32:00        70079
# 4  136116       10127   182839 2198-07-17 2198-07-17 10:17:00        70026
#
#      spec_type_desc  org_itemid org_name  isolate_num  ab_itemid ab_name  \
# 0             URINE         NaN     None          NaN        NaN    None
# 1     BLOOD CULTURE         NaN     None          NaN        NaN    None
# 2     BLOOD CULTURE         NaN     None          NaN        NaN    None
# 3             URINE         NaN     None          NaN        NaN    None
# 4  CSF;SPINAL FLUID         NaN     None          NaN        NaN    None
#
#   dilution_text dilution_comparison  dilution_value interpretation
# ...

# %%
sql_query = """
SELECT * FROM admissions;
"""
admissions = pd.read_sql_query(sql_query,con)
admissions.head()
# Out:
#    row_id  subject_id  hadm_id           admittime           dischtime  \
# 0   12258       10006   142345 2164-10-23 21:09:00 2164-11-01 17:15:00
# 1   12263       10011   105331 2126-08-14 22:32:00 2126-08-28 18:59:00
# 2   12265       10013   165520 2125-10-04 23:36:00 2125-10-07 15:13:00
# 3   12269       10017   199207 2149-05-26 17:19:00 2149-06-03 18:42:00
# 4   12270       10019   177759 2163-05-14 20:43:00 2163-05-15 12:00:00
#
#             deathtime admission_type         admission_location  \
# 0                 NaT      EMERGENCY       EMERGENCY ROOM ADMIT
# 1 2126-08-28 18:59:00      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 2 2125-10-07 15:13:00      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3                 NaT      EMERGENCY       EMERGENCY ROOM ADMIT
# 4 2163-05-15 12:00:00      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
#
#   discharge_location insurance language  religion marital_status  \
# 0   HOME HEALTH CARE  Medicare     None  CATHOLIC      SEPARATED
# ...

# %%
sql_query = """
SELECT * FROM diagnoses_icd;
"""
diagnoses = pd.read_sql_query(sql_query,con)
diagnoses.head()
# Out:
#    row_id  subject_id  hadm_id  seq_num icd9_code
# 0  112565       10032   140372        3      5070
# 1  112566       10032   140372        4     42830
# 2  112567       10032   140372        5      4280
# 3  112568       10032   140372        6      2851
# 4  112569       10032   140372        7      2765

# %%
# need to get set of subject_id's associated with one or more icd codes whose 
# first 3 digits are lower than 140
# first remove rows with codes starting with V or E

diagnoses['icd9_letter'] = diagnoses.icd9_code.str[0]
diagnoses = diagnoses[(diagnoses.icd9_letter != 'E') & (diagnoses.icd9_letter != 'V')]
diagnoses['icd9_3digit'] = diagnoses.icd9_code.str[:3]
diagnoses.icd9_3digit = pd.to_numeric(diagnoses.icd9_3digit)

# %%
diagnoses.head()
# Out:
#    row_id  subject_id  hadm_id  seq_num icd9_code icd9_letter  icd9_3digit
# 0  112565       10032   140372        3      5070           5          507
# 1  112566       10032   140372        4     42830           4          428
# 2  112567       10032   140372        5      4280           4          428
# 3  112568       10032   140372        6      2851           2          285
# 4  112569       10032   140372        7      2765           2          276

# %%
infect_diagnoses = diagnoses[(diagnoses.icd9_3digit < 140)]
infected_pts = set(infect_diagnoses.subject_id)
len(infected_pts)

# %%
diagnoses[diagnoses.subject_id == 10083]
# Out:
#      row_id  subject_id  hadm_id  seq_num icd9_code icd9_letter  icd9_3digit
# 200  113033       10083   134993        4       261           2          261
# 201  113034       10083   134993        5      5990           5          599
# 202  113035       10083   134993        6      4280           4          428
# 203  113036       10083   134993        7     58181           5          581
# 204  113037       10083   134993        8     27652           2          276
# 205  113038       10083   134993        9      5780           5          578
# 206  113039       10083   134993       10      2762           2          276
# 207  113040       10083   134993       11      2761           2          276
# 208  113041       10083   134993       12      7907           7          790
# 210  113043       10083   134993       14      2739           2          273
# 211  113044       10083   134993       15     45829           4          458
# ...

# %%
infect_diagnoses.head()
# Out:
#     row_id  subject_id  hadm_id  seq_num icd9_code icd9_letter  icd9_3digit
# 23  112590       10036   189483        1      0389           0           38
# 38  112612       10038   111115        2      0380           0           38
# 56  112630       10038   111115       20     04102           0           41
# 78  112666       10043   168674        4     00845           0            8
# 92  112680       10045   126949        1      0383           0           38

# %%
infect_admits = admissions[admissions.subject_id.isin(infected_pts)]

# %%
infect_admits.hospital_expire_flag.value_counts()
# Out:
# 0    45
# 1    20
# Name: hospital_expire_flag, dtype: int64

# %%
shape(infect_admits)
# Out:
# (65, 19)

# %%
infect_admits
# Out:
#      row_id  subject_id  hadm_id           admittime           dischtime  \
# 0     12258       10006   142345 2164-10-23 21:09:00 2164-11-01 17:15:00
# 1     12263       10011   105331 2126-08-14 22:32:00 2126-08-28 18:59:00
# 2     12265       10013   165520 2125-10-04 23:36:00 2125-10-07 15:13:00
# 4     12270       10019   177759 2163-05-14 20:43:00 2163-05-15 12:00:00
# 7     12280       10029   132349 2139-09-22 10:58:00 2139-10-02 14:29:00
# 11    12286       10036   189483 2185-03-24 16:56:00 2185-03-26 09:15:00
# 12    12288       10038   111115 2144-02-09 17:53:00 2144-02-21 13:30:00
# 15    12293       10043   168674 2185-04-14 00:23:00 2185-04-26 18:20:00
# 17    12295       10045   126949 2129-11-24 00:31:00 2129-12-01 01:45:00
# 19    12305       10056   100375 2129-05-02 00:12:00 2129-05-06 13:40:00
# 20    12308       10059   142582 2150-08-07 21:40:00 2150-08-13 11:33:00
# 21    12309       10059   122098 2150-08-22 17:33:00 2150-08-29 18:20:00
# ...

# %%
import seaborn as sns

# %%
sql_query = """
SELECT * FROM patients;
"""
patients = pd.read_sql_query(sql_query,con)
patients.head()
# Out:
#    row_id  subject_id gender        dob        dod   dod_hosp    dod_ssn  \
# 0    9467       10006      F 2094-03-05 2165-08-12 2165-08-12 2165-08-12
# 1    9472       10011      F 2090-06-05 2126-08-28 2126-08-28        NaT
# 2    9474       10013      F 2038-09-03 2125-10-07 2125-10-07 2125-10-07
# 3    9478       10017      F 2075-09-21 2152-09-12        NaT 2152-09-12
# 4    9479       10019      M 2114-06-20 2163-05-15 2163-05-15 2163-05-15
#
#    expire_flag
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
infect_pts = infect_admits.join(patients.set_index('subject_id'), on='subject_id', how='left', lsuffix='_ad', rsuffix='_pt', sort=False)

# %%
#p = 'doubling time'
#g = sns.factorplot(y='', x='name', col='media', data=gc, order=strain_list, 
#                   kind='box', legend=False, aspect=1, sharey=False, size=3,
#                   fliersize=3, whis=1.5,  color=u'#818181',
#                   col_order=['YPD', '0.5 M NaCl'])
g = sns.countplot(x='hospital_expire_flag', hue='ethnicity', data=infect_pts)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Patient outcomes and ethnicity')
plt.savefig('/Users/nwespe/Desktop/pt_expire_ethnicity.png', bbox_inches='tight')
